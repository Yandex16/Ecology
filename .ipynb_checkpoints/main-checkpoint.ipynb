# %%
import pandas as pd

# %%
PATH = 'analysing_environmental_issues.csv'
df = pd.read_csv(PATH, sep=",")

# %% [markdown]
# #### Обработка выбросов

# %%
# %run remove_outliers/remove_outliers_run.ipynb

df = hybrid_outlier_handling(df, df.columns[1:])
Для проверки, что все работает
draw_boxplots_for_all_columns(df)
draw_histograms_for_all_columns(df)

# %% [markdown]
# #### Замена пропусков

# %%
# %run nans_substitution_regression_modeling/replacement_nan_values_except_stage4gas.ipynb

# %% [markdown]
# #### Проверка гипотез

# %%
# %run hypothesis_testing/hypothesis_testing_run.ipynb

# Тут просто результат, все с графиками и тестами в hypothesis_testing.ipynb
test_hypothesis_1(df)
test_hypothesis_2(df)
test_hypothesis_3(df)
test_hypothesis_4(df)
test_hypothesis_5(df)
test_hypothesis_6(df)
test_hypothesis_7(df)
# Out:
# Проверка гипотезы 1:
# Не удалось отклонить нулевую гипотезу: Доля газа НЕ зависит от смены.
#
# Проверка гипотезы 2:
# Нет статистически значимой разницы между сменами, но у Смена 2 ниже средняя температура.
#
# Проверка гипотезы 3:
# Не удается отклонить нулевую гипотезу: Значимой связи между конверсией мономера и количеством подаваемой воды нет.
#
# Проверка гипотезы 4:
# Значимой связи между долей опасного газа и количеством выходного продукта не обнаружено.
#
# Проверка гипотезы 5:
# Результат: Есть статистически значимая связь между количеством полимера на входе и количеством выходного продукта.
#
# Проверка гипотезы 6:
# Результат: Значимой связи между вакуумом на 2 этапе и продуктом на 4 этапе не обнаружено.
#
# Проверка гипотезы 7:
# Результат: Есть статистически значимая связь между температурой верха на 3 этапе и средним остатком на 4 этапе.
# C:\Users\user\AppData\Local\Temp\ipykernel_17972\117736757.py:3: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   stat, p_value = shapiro(data)
# C:\Users\user\AppData\Local\Temp\ipykernel_17972\3163378110.py:18: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   u_stat, p_value = mannwhitneyu(shift_1, shift_2, alternative='two-sided')

# %% [markdown]
# #### Расчеты

# %%
# %run calculations/calculations.ipynb
# Out:
# статистика расхода по стадиям:
#           stage_2       stage_3       stage_4
# count  371.000000    371.000000    371.000000
# mean    50.516642  13573.682334   5535.436054
# std     39.096808  11920.977011   4520.531250
# min      3.706474    312.180000    294.040229
# 25%      9.240332   1810.640000    868.705000
# 50%     51.316477  11701.120000   5191.606529
# 75%     91.869837  24021.733456   9567.251850
# max    125.512257  48115.606470  15697.374826
#
#  10 дней с максимальным потреблением
#
# stage_2:
# DateTime
# 2021-04-15    125.512257
# 2021-02-14    117.626913
# 2021-02-13    116.919684
# 2021-02-07    116.883094
# 2021-02-06    116.876080
# 2021-08-07    115.406865
# 2021-03-18    114.449820
# 2021-02-24    112.345354
# 2021-02-23    112.147921
# 2022-06-12    110.833700
# Name: stage_2, dtype: float64
#
# stage_3:
# DateTime
# 2021-02-06    48115.606470
# 2021-02-07    47568.165918
# 2021-03-18    40660.990000
# 2022-02-24    38460.156600
# 2022-02-25    37936.980000
# 2021-12-14    37514.820000
# 2022-07-21    37386.106140
# 2022-07-23    37272.765000
# 2022-07-22    37151.220000
# 2022-02-23    36931.636100
# Name: stage_3, dtype: float64
#
# stage_4:
# DateTime
# 2022-08-08    15697.374826
# 2022-07-23    15389.418468
# 2021-04-07    14551.801364
# 2022-08-01    14498.162604
# 2021-04-15    14494.463100
# 2022-07-31    14375.630356
# 2021-02-07    14351.138800
# 2021-02-06    14290.235350
# 2022-07-25    13957.886854
# 2022-07-22    13947.522700
# Name: stage_4, dtype: float64
#
# ___ Статистика ежедневного потребления ресурсов: ___
#
# ------------------------------------------------------------
# Среднее потребление: 19159.64
# Стандартное отклонение: 16211.01
# Минимальное потребление: 633.21
# Максимальное потребление: 62522.72
# Медианное потребление: 17729.11
# ------------------------------------------------------------
#
# ___ Периоды повышенного потребления: ___
#
# Период: 2021-02-06 - 2021-02-07
# Длительность: 2 дней
# Среднее потребление: 62279.45
#
# Период: 2021-02-12 - 2021-02-14
# Длительность: 3 дней
# Среднее потребление: 45651.13
#
# Период: 2021-02-23 - 2021-02-24
# Длительность: 2 дней
# Среднее потребление: 46225.20
#
# Период: 2021-03-28 - 2021-03-30
# Длительность: 3 дней
# Среднее потребление: 38590.36
#
# Период: 2021-04-14 - 2021-04-15
# Длительность: 2 дней
# Среднее потребление: 39682.75
#
# Период: 2021-11-22 - 2021-12-03
# Длительность: 12 дней
# Среднее потребление: 38608.52
#
# Период: 2021-12-05 - 2021-12-07
# Длительность: 3 дней
# Среднее потребление: 38792.89
#
# Период: 2021-12-10 - 2021-12-11
# Длительность: 2 дней
# Среднее потребление: 38428.05
#
# Период: 2021-12-21 - 2021-12-28
# Длительность: 8 дней
# Среднее потребление: 42310.08
#
# Период: 2022-01-19 - 2022-01-20
# Длительность: 2 дней
# Среднее потребление: 41767.21
#
# Период: 2022-02-22 - 2022-03-01
# Длительность: 8 дней
# Среднее потребление: 47730.10
#
# Период: 2022-03-29 - 2022-04-01
# Длительность: 4 дней
# Среднее потребление: 37762.22
#
# Период: 2022-04-08 - 2022-04-11
# Длительность: 4 дней
# Среднее потребление: 36120.06
#
# Период: 2022-06-12 - 2022-06-13
# Длительность: 2 дней
# Среднее потребление: 39834.37
#
# Период: 2022-06-15 - 2022-06-18
# Длительность: 4 дней
# Среднее потребление: 37786.07
#
# Период: 2022-07-17 - 2022-07-18
# Длительность: 2 дней
# Среднее потребление: 42608.99
#
# Период: 2022-07-20 - 2022-07-24
# Длительность: 5 дней
# Среднее потребление: 48115.94
# ------------------------------------------------------------
# Сводная таблица по месяцам:
#
# Распределение категорий по месяцам:
# 2021-01
# DateTime  danger_category
# 2021-01   2.0                6
#           3.0                3
# Name: count, dtype: int64
# ----------------------------
# 2021-02
# DateTime  danger_category
# 2021-02   2.0                61
#           3.0                22
# Name: count, dtype: int64
# ----------------------------
# 2021-03
# DateTime  danger_category
# 2021-03   2.0                59
#           1.0                 2
#           3.0                 2
# Name: count, dtype: int64
# ----------------------------
# 2021-04
# DateTime  danger_category
# 2021-04   2.0                38
#           3.0                17
# Name: count, dtype: int64
# ----------------------------
# 2021-08
# DateTime  danger_category
# 2021-08   2.0                8
# Name: count, dtype: int64
# ----------------------------
# 2021-09
# DateTime  danger_category
# 2021-09   2.0                3
# Name: count, dtype: int64
# ----------------------------
# 2021-11
# DateTime  danger_category
# 2021-11   2.0                37
#           3.0                16
# Name: count, dtype: int64
# ----------------------------
# 2021-12
# DateTime  danger_category
# 2021-12   2.0                67
#           3.0                40
#           1.0                 2
# Name: count, dtype: int64
# ----------------------------
# 2022-01
# DateTime  danger_category
# 2022-01   2.0                13
#           3.0                 6
# Name: count, dtype: int64
# ----------------------------
# 2022-02
# DateTime  danger_category
# 2022-02   2.0                40
#           3.0                12
# Name: count, dtype: int64
# ----------------------------
# 2022-03
# DateTime  danger_category
# 2022-03   2.0                49
#           3.0                27
# Name: count, dtype: int64
# ----------------------------
# 2022-04
# DateTime  danger_category
# 2022-04   2.0                45
#           3.0                15
# Name: count, dtype: int64
# ----------------------------
# 2022-05
# DateTime  danger_category
# 2022-05   2.0                5
#           3.0                1
# Name: count, dtype: int64
# ----------------------------
# 2022-06
# DateTime  danger_category
# 2022-06   2.0                48
#           3.0                 6
#           1.0                 2
# Name: count, dtype: int64
# ----------------------------
# 2022-07
# DateTime  danger_category
# 2022-07   2.0                53
#           3.0                10
#           1.0                 1
# Name: count, dtype: int64
# ----------------------------
# 2022-08
# DateTime  danger_category
# 2022-08   2.0                40
#           3.0                19
#           1.0                 1
# Name: count, dtype: int64
# ----------------------------
# 2022-09
# DateTime  danger_category
# 2022-09   2.0                49
#           3.0                 4
# Name: count, dtype: int64
# ----------------------------
# 2022-10
# DateTime  danger_category
# 2022-10   2.0                35
#           3.0                 8
# Name: count, dtype: int64
# ----------------------------
# 2022-11
# DateTime  danger_category
# 2022-11   2.0                18
#           3.0                 9
# Name: count, dtype: int64
# ----------------------------
# 2022-12
# DateTime  danger_category
# 2022-12   2.0                8
#           3.0                8
# Name: count, dtype: int64
# ----------------------------
# 2023-03
# DateTime  danger_category
# 2023-03   2.0                10
#           3.0                 9
# Name: count, dtype: int64
# ----------------------------
# ===========================================
# СТАДИЯ 1
# ===========================================
# C:\Users\user\AppData\Local\Temp\ipykernel_17972\3685374072.py:52: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_avg = daily_total.resample('M').mean()
# C:\Users\user\AppData\Local\Temp\ipykernel_17972\3685374072.py:53: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   monthly_trend = monthly_avg.pct_change()
# Конверсия сырья:
# Низкая категория: 66.04
# Средняя категория: 69.05 (изменение: 4.6%)
# Высокая категория: 69.27 (изменение: 0.3%)
# ===========================================
# СТАДИЯ 2
# ===========================================
# Подача воды:
# Низкая категория: 4.34
# Средняя категория: 4.44 (изменение: 2.3%)
# Высокая категория: 4.42 (изменение: -0.5%)
#
# Давление низа:
# Низкая категория: 374.11
# Средняя категория: 395.94 (изменение: 5.8%)
# Высокая категория: 392.90 (изменение: -0.8%)
# !!! Значимое изменение !!!
#
# Температура низа:
# Низкая категория: 4.37
# Средняя категория: 4.38 (изменение: 0.2%)
# Высокая категория: 4.38 (изменение: 0.0%)
#
# Температура пара низа:
# Низкая категория: 101.95
# Средняя категория: 97.90 (изменение: -4.0%)
# Высокая категория: 97.60 (изменение: -0.3%)
#
# Вакуум низа:
# Низкая категория: 54.06
# Средняя категория: 56.34 (изменение: 4.2%)
# Высокая категория: 56.96 (изменение: 1.1%)
#
# Давление верха:
# Низкая категория: 1.96
# Средняя категория: 1.96 (изменение: 0.0%)
# Высокая категория: 1.96 (изменение: 0.0%)
#
# Давление верха на выходе:
# Низкая категория: 263.26
# Средняя категория: 261.18 (изменение: -0.8%)
# Высокая категория: 261.06 (изменение: -0.0%)
#
# Температура верха:
# Низкая категория: 94.42
# Средняя категория: 94.62 (изменение: 0.2%)
# Высокая категория: 95.25 (изменение: 0.7%)
#
# Вакуум верха:
# Низкая категория: 61.63
# Средняя категория: 59.12 (изменение: -4.1%)
# Высокая категория: 56.48 (изменение: -4.5%)
# ===========================================
# СТАДИЯ 3
# ===========================================
# Подаваемое давление:
# Низкая категория: 0.34
# Средняя категория: 0.33 (изменение: -2.9%)
# Высокая категория: 0.32 (изменение: -3.0%)
#
# Подача смягченной воды:
# Низкая категория: 330.61
# Средняя категория: 300.02 (изменение: -9.3%)
# Высокая категория: 305.68 (изменение: 1.9%)
# !!! Значимое изменение !!!
#
# Подача пара:
# Низкая категория: 786.35
# Средняя категория: 821.72 (изменение: 4.5%)
# Высокая категория: 828.27 (изменение: 0.8%)
#
# Температура пара:
# Низкая категория: 1.01
# Средняя категория: 1.01 (изменение: 0.0%)
# Высокая категория: 1.01 (изменение: 0.0%)
#
# Температура верха:
# Низкая категория: 41.50
# Средняя категория: 42.53 (изменение: 2.5%)
# Высокая категория: 42.81 (изменение: 0.7%)
# ===========================================
# СТАДИЯ 4
# ===========================================
# Подача перегретого пара:
# Низкая категория: 153.09
# Средняя категория: 153.28 (изменение: 0.1%)
# Высокая категория: 153.14 (изменение: -0.1%)
#
# Подача полимера:
# Низкая категория: 18.75
# Средняя категория: 20.11 (изменение: 7.3%)
# Высокая категория: 20.17 (изменение: 0.3%)
# !!! Значимое изменение !!!
#
# Подача пара:
# Низкая категория: 4.49
# Средняя категория: 5.28 (изменение: 17.6%)
# Высокая категория: 5.55 (изменение: 5.1%)
# !!! Значимое изменение !!!
#
# Подача воды:
# Низкая категория: 243.88
# Средняя категория: 292.02 (изменение: 19.7%)
# Высокая категория: 299.47 (изменение: 2.6%)
# !!! Значимое изменение !!!
#
# Сухой остаток:
# Низкая категория: 21.30
# Средняя категория: 22.29 (изменение: 4.6%)
# Высокая категория: 22.50 (изменение: 0.9%)
#
# Готовый продукт:
# Низкая категория: 44.03
# Средняя категория: 44.06 (изменение: 0.1%)
# Высокая категория: 42.30 (изменение: -4.0%)

# %% [markdown]
# #### Регрессионное моделирование

# %%
df.shape
# Out:
# (4240, 24)

# %%
# %run regression_modeling/danger_gas_prediction_model.ipynb
# Out:
# Показатели модели SVR:
# Лучшая пара метрик: R2 = -0.0778, MAPE = 0.2723
# Метрики оценены на основе следующих факторов: ['DateTime', 'stage_1_output_konv_avd', 'stage_2_input_water_sum', 'stage_2_output_bottom_pressure', 'stage_2_output_bottom_temp', 'stage_2_output_bottom_temp_hum_steam', 'stage_2_output_bottom_vacuum', 'stage_2_output_top_pressure', 'stage_2_output_top_pressure_at_end', 'stage_2_output_top_temp', 'stage_2_output_top_vacuum', 'stage_3_input_pressure', 'stage_3_input_soft_water', 'stage_3_input_steam', 'stage_3_output_temp_hum_steam', 'stage_3_output_temp_top', 'stage_4_input_overheated_steam', 'stage_4_input_polymer', 'stage_4_input_steam', 'stage_4_input_water', 'stage_4_output_dry_residue_avg', 'stage_4_output_product', 'work_shift']
# =-----------------------------------------------
# Показатели модели Decision Tree Regressor:
# Лучшая пара метрик: R2 = 0.1215, MAPE = 0.2109
# Метрики оценены на основе следующих факторов: ['stage_2_output_bottom_pressure', 'stage_2_output_bottom_temp', 'stage_2_output_bottom_temp_hum_steam', 'stage_2_output_top_pressure', 'stage_2_output_top_pressure_at_end', 'stage_2_output_top_temp', 'stage_2_output_top_vacuum', 'stage_3_input_pressure', 'stage_3_input_steam', 'stage_4_input_overheated_steam', 'stage_4_input_polymer', 'stage_4_input_steam', 'stage_4_input_water', 'stage_4_output_dry_residue_avg', 'stage_4_output_product', 'work_shift']
# =-----------------------------------------------
# Показатели модели Gradient Boosting Regressor:
# Лучшая пара метрик: R2 = 0.3697, MAPE = 0.1850
# Метрики оценены на основе следующих факторов: ['DateTime', 'stage_1_output_konv_avd', 'stage_2_input_water_sum', 'stage_2_output_bottom_pressure', 'stage_2_output_bottom_temp', 'stage_2_output_bottom_temp_hum_steam', 'stage_2_output_top_pressure', 'stage_2_output_top_pressure_at_end', 'stage_2_output_top_temp', 'stage_2_output_top_vacuum', 'stage_3_input_pressure', 'stage_3_input_steam', 'stage_3_output_temp_hum_steam', 'stage_3_output_temp_top', 'stage_4_input_overheated_steam', 'stage_4_input_polymer', 'stage_4_input_steam', 'stage_4_output_dry_residue_avg', 'stage_4_output_product']
# =-----------------------------------------------
# Показатели модели K-Nearest Neighbors Regressor (n_neighbors = 5):
# Лучшая пара метрик: R2 = 0.2963, MAPE = 0.1886
# Метрики оценены на основе следующих факторов: ['DateTime', 'stage_2_input_water_sum', 'stage_2_output_bottom_pressure', 'stage_2_output_bottom_temp_hum_steam', 'stage_2_output_top_temp', 'stage_3_input_pressure', 'stage_3_input_soft_water', 'stage_3_input_steam', 'stage_3_output_temp_top', 'stage_4_input_overheated_steam', 'stage_4_input_polymer', 'stage_4_input_steam', 'stage_4_output_product', 'work_shift']
# =-----------------------------------------------
# Показатели модели K-Nearest Neighbors Regressor (n_neighbors = 3):
# Лучшая пара метрик: R2 = 0.2399, MAPE = 0.2028
# Метрики оценены на основе следующих факторов: ['DateTime', 'stage_2_input_water_sum', 'stage_2_output_bottom_temp', 'stage_2_output_bottom_temp_hum_steam', 'stage_2_output_bottom_vacuum', 'stage_2_output_top_pressure', 'stage_2_output_top_pressure_at_end', 'stage_2_output_top_vacuum', 'stage_3_input_pressure', 'stage_3_input_soft_water', 'stage_3_input_steam', 'stage_3_output_temp_hum_steam', 'stage_3_output_temp_top', 'stage_4_input_overheated_steam', 'stage_4_input_polymer', 'stage_4_input_water', 'stage_4_output_dry_residue_avg', 'stage_4_output_product']
# =-----------------------------------------------
# Показатели модели Random Forest Regressor:

# %% [markdown]
# ## Выводы:
#
# ### Оценка метрик: **R2 = 0.4014 и MAPE = 0.1766**. Модель Random Forest Regressor.
#
# #### **Неудовлетворительная прогностическая способность модели**: Проведенный анализ показал, что среди протестированных моделей наилучшие результаты достигнуты с помощью Random Forest Regressor (RFR), однако даже эта модель не продемонстрировала удовлетворительной прогностической способности в отношении доли опасного газа. Остальные модели, включая SVR, Decision Tree Regressor, Gradient Boosting Regressor, K-Nearest Neighbors Regressor (с n_neighbors = 5 и 3), показали худшие результаты. Несмотря на то, что RFR показал лучшие метрики (R2 = 0.4014 и MAPE = 0.1766), они по-прежнему свидетельствуют о том, что модель объясняет лишь небольшую долю дисперсии целевой переменной, а предсказания имеют значительные отклонения от фактических значений. Таким образом, RFR является лучшим выбором из рассмотренных моделей, но его прогностическая сила остается недостаточной.
#
# #### **Недопустимость замены ручных замеров на основе текущей модели**: Принимая во внимание низкие показатели прогностической точности модели и существенную величину погрешности предсказаний, её использование в качестве замены ручных замеров доли опасного газа является недопустимым. Ошибки в предсказаниях, достигающие в среднем 19%, могут иметь критические последствия, особенно в контексте мониторинга потенциально опасных веществ. Таким образом, текущая модель не обеспечивает требуемой надежности и точности для принятия ответственных решений.
