# %%
import pandas as pd

# %% [markdown]
# #### Обработка выбросов

# %% [markdown]
# Обработка выбросов запускается из файла remove_outliers/remove_outliers_run.ipynb.

# %%
# %run remove_outliers/remove_outliers_run.ipynb

# df = hybrid_outlier_handling(df, df.columns[1:])
# # Для проверки, что все работает
# # draw_boxplots_for_all_columns(df)
# # draw_histograms_for_all_columns(df)

# %% [markdown]
# #### Замена пропусков

# %% [markdown]
# Замена пропусков происходит в nans_substitution_regression_modeling/replacement_nan_values_except_stage4gas.ipynb. Там же и происходит обработка выбросов. Так как код для замены NaN-ов работает небыстро, мы решили результат работы экспортировать в отдельный .csv файл, чтобы быстрее тестировать.

# %%
# %run nans_substitution_regression_modeling/replacement_nan_values_except_stage4gas.ipynb

df = pd.read_csv('data_imputed_stage4gas_unfilled.csv', sep=",")

# %% [markdown]
# #### Проверка гипотез

# %%
# %run hypothesis_testing/hypothesis_testing_run.ipynb

# Тут просто результат, все с графиками и тестами в hypothesis_testing.ipynb
test_hypothesis_1(df)
test_hypothesis_2(df)
test_hypothesis_3(df)
test_hypothesis_4(df)
test_hypothesis_5(df)
test_hypothesis_6(df)
test_hypothesis_7(df)
# Out:
# Проверка гипотезы 1:
# Не удалось отклонить нулевую гипотезу: Доля газа НЕ зависит от смены.
#
# Проверка гипотезы 2:
# Нет статистически значимой разницы между сменами, но у Смена 2 ниже средняя температура.
#
# Проверка гипотезы 3:
# Не удается отклонить нулевую гипотезу: Значимой связи между конверсией мономера и количеством подаваемой воды нет.
#
# Проверка гипотезы 4:
# Значимой связи между долей опасного газа и количеством выходного продукта не обнаружено.
#
# Проверка гипотезы 5:
# Результат: Есть статистически значимая связь между количеством полимера на входе и количеством выходного продукта.
#
# Проверка гипотезы 6:
# Результат: Значимой связи между вакуумом на 2 этапе и продуктом на 4 этапе не обнаружено.
#
# Проверка гипотезы 7:
# Результат: Есть статистически значимая связь между температурой верха на 3 этапе и средним остатком на 4 этапе.
# ...

# %% [markdown]
# #### Расчеты

# %%
# %run calculations/calculations.ipynb
# Out:
# статистика расхода по стадиям:
#           stage_2       stage_3       stage_4
# count  331.000000    331.000000    331.000000
# mean    56.541850  15231.652577   6288.785035
# std     40.105833  12077.915134   4723.723321
# min      3.464106    530.960000    328.450000
# 25%      9.267777   2826.100000   1155.840000
# 50%     58.107651  14893.480400   6321.759800
# 75%     96.457526  25489.987350  10048.372200
# max    125.566045  48131.424500  17438.960000
#
#  10 дней с максимальным потреблением
#
# stage_2:
# DateTime
# 2021-04-15    125.566045
# 2021-02-14    117.627183
# 2021-02-13    116.925149
# 2021-02-07    116.883094
# 2021-02-06    116.876080
# 2021-08-07    115.406865
# 2022-05-12    115.080226
# 2021-03-18    114.449004
# 2022-08-07    114.434297
# 2022-08-06    113.801945
# Name: stage_2, dtype: float64
#
# stage_3:
# DateTime
# 2021-02-06    48131.4245
# 2021-02-07    47577.5750
# 2022-02-22    40664.2007
# 2021-03-18    40660.9900
# 2022-07-16    40496.9200
# ...

# %% [markdown]
# #### Регрессионное моделирование

# %%
print(df.shape)
df = df.drop('danger_category', axis=1)
print(df.isna().any())
# Out:
# (4240, 25)
# DateTime                                False
# stage_1_output_konv_avd                 False
# stage_2_input_water_sum                 False
# stage_2_output_bottom_pressure          False
# stage_2_output_bottom_temp              False
# stage_2_output_bottom_temp_hum_steam    False
# stage_2_output_bottom_vacuum            False
# stage_2_output_top_pressure             False
# stage_2_output_top_pressure_at_end      False
# stage_2_output_top_temp                 False
# stage_2_output_top_vacuum               False
# stage_3_input_pressure                  False
# stage_3_input_soft_water                False
# stage_3_input_steam                     False
# stage_3_output_temp_hum_steam           False
# stage_3_output_temp_top                 False
# stage_4_input_overheated_steam          False
# stage_4_input_polymer                   False
# stage_4_input_steam                     False
# stage_4_input_water                     False
# ...

# %%
# %run regression_modeling/danger_gas_prediction_model.ipynb
# Out:
# Показатели модели SVR:
# Лучшая пара метрик: R2 = 0.0161, MAPE = 0.2620
# Метрики оценены на основе следующих факторов: ['stage_2_output_bottom_temp', 'stage_2_output_top_pressure', 'stage_2_output_top_pressure_at_end', 'stage_3_output_temp_top', 'stage_4_input_overheated_steam', 'stage_4_input_polymer', 'stage_4_input_water', 'stage_4_output_dry_residue_avg']
# =-----------------------------------------------
# Показатели модели Decision Tree Regressor:
# Лучшая пара метрик: R2 = 0.0616, MAPE = 0.2096
# Метрики оценены на основе следующих факторов: ['stage_1_output_konv_avd', 'stage_2_input_water_sum', 'stage_2_output_bottom_temp', 'stage_2_output_bottom_vacuum', 'stage_2_output_top_pressure', 'stage_2_output_top_temp', 'stage_3_input_pressure', 'stage_3_input_soft_water', 'stage_3_input_steam', 'stage_4_input_overheated_steam', 'stage_4_input_polymer', 'stage_4_input_steam', 'stage_4_input_water', 'stage_4_output_dry_residue_avg', 'stage_4_output_product', 'work_shift']
# ...

# %% [markdown]
# ## Выводы:
#
# ### Оценка метрик: **R2 = 0.3802 и MAPE = 0.1780**. Модель Random Forest Regressor.
#
# #### **Неудовлетворительная прогностическая способность модели**: Проведенный анализ показал, что среди протестированных моделей наилучшие результаты достигнуты с помощью Random Forest Regressor (RFR), однако даже эта модель не продемонстрировала удовлетворительной прогностической способности в отношении доли опасного газа. Остальные модели, включая SVR, Decision Tree Regressor, Gradient Boosting Regressor, K-Nearest Neighbors Regressor (с n_neighbors = 5 и 3), показали худшие результаты. Несмотря на то, что RFR показал лучшие метрики (R2 = 0.3802 и MAPE = 0.1780), они по-прежнему свидетельствуют о том, что модель объясняет лишь небольшую долю дисперсии целевой переменной, а предсказания имеют значительные отклонения от фактических значений. Таким образом, RFR является лучшим выбором из рассмотренных моделей, но его прогностическая сила остается недостаточной.
#
# #### **Недопустимость замены ручных замеров на основе текущей модели**: Принимая во внимание низкие показатели прогностической точности модели и существенную величину погрешности предсказаний, её использование в качестве замены ручных замеров доли опасного газа является недопустимым. Ошибки в предсказаниях, достигающие в среднем 18%, могут иметь критические последствия, особенно в контексте мониторинга потенциально опасных веществ. Таким образом, текущая модель не обеспечивает требуемой надежности и точности для принятия ответственных решений.
