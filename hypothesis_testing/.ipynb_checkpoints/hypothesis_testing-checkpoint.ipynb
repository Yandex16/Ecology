# %% [markdown]
# ### Проверка гипотез
# - \[ \] Гипотеза 1. Если ли различия в доле опасного газа от смены?
# - \[ \] Гипотеза 2. Какая из смен лучше управляет температурой верха на этапе 3? Считать, что высокая температура хуже.
# - \[ \] Гипотеза 3. Конверсия мономера на 1 этапе влияет на количество подаваемой суммарной воды.
# - \[ \] Гипотеза 4. Количество выходного количества продукта связано с долей опасного газа
# - \[ \] Гипотезы 5-7. Дополнительно выдвинуть и проверить не менее 3 гипотез по влиянию разных факторов на любой из выходных параметров этапа 4.

# %%
import pandas as pd
from scipy.stats import shapiro, ttest_ind, mannwhitneyu, spearmanr
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def draw_separation_line():
    print("\n" * 2 + "#" * 120 + "\n" * 2)

# %%
def is_normal_distribution(data, alpha=0.05):
    """Проверка нормальности распределения с помощью теста Шапиро-Уилка."""
    stat, p_value = shapiro(data)
    print(f"Тест Шапиро-Уилка: W-статистика = {stat:.4f}, p-значение = {p_value:.2e}")
    return p_value > alpha  # True, если данные нормально распределены

def print_summary_statistics(label, data):
    """Вывод основных статистических характеристик."""
    print(f"{label}:")
    print(f"  Среднее значение = {data.mean():.4f}")
    print(f"  Медиана = {data.median():.4f}")
    print(f"  Стандартное отклонение = {data.std():.4f}")
    print(f"  Размер выборки = {len(data)}\n")

def interpret_ttest(t_stat, p_value, group1, group2):
    """Интерпретация результатов t-теста."""
    print(f"Student's t-test:")
    print(f"  T-статистика: {t_stat:.4f}, p-значение: {p_value:.4f}")
    if p_value < 0.05:
        print("  Результат: Есть статистически значимая разница между сменами.")
        # Расчет размера эффекта (Cohen's d)
        pooled_std = ((group1.std() ** 2 + group2.std() ** 2) / 2) ** 0.5
        cohen_d = (group1.mean() - group2.mean()) / pooled_std
        print(f"  Размер эффекта (Cohen's d): {cohen_d:.4f}")
        if abs(cohen_d) < 0.2:
            print("  Сила эффекта: крайне мала.")
        elif abs(cohen_d) < 0.5:
            print("  Сила эффекта: малая.")
        elif abs(cohen_d) < 0.8:
            print("  Сила эффекта: средняя.")
        else:
            print("  Сила эффекта: большая.")
    else:
        print("  Результат: Статистически значимых различий между сменами нет.")

def correlation_strength(corr):
    """
    Определяет силу корреляции по коэффициенту корреляции.
    """
    if abs(corr) < 0.1:
        return "Однако связь крайне слабая."
    elif abs(corr) < 0.3:
        return "Связь слабая."
    elif abs(corr) < 0.5:
        return "Связь умеренная."
    else:
        return "Связь сильная."

def interpret_mannwhitney(u_stat, p_value, group1, group2):
    """Интерпретация результатов теста Манна-Уитни."""
    print("Mann-Whitney U Test:")
    print(f"  U-статистика: {u_stat:.4f}, p-значение: {p_value:.4f}")
    if p_value < 0.05:
        print("  Результат: Есть статистически значимая разница между сменами.")
        # Расчет эффекта (размер эффекта r)
        r = u_stat / (len(group1) * len(group2))  # Normalized U-statistic
        print(f"  Размер эффекта (r): {r:.4f}")
        if abs(r) < 0.1:
            print("  Сила эффекта: крайне мала.")
        elif abs(r) < 0.3:
            print("  Сила эффекта: малая.")
        elif abs(r) < 0.5:
            print("  Сила эффекта: средняя.")
        else:
            print("  Сила эффекта: большая.")
    else:
        print("  Результат: Статистически значимых различий между сменами нет.")

# %% [markdown]
# ### Проверка гипотезы 1

# %% [markdown]
# По сути есть ли зависимость `stage_4_output_danger_gas` и `work_shift`.

# %% [markdown]
# Для начала разделяем `stage_4_output_danger_gas` на две смены `work_shift=1` `worsk_shift=2`. Проверяем на нормальность с помощью Shapiro и на основе этого применяем или U-критерий Манна — Уитни, или t-критерий Стьюдента.

# %%
def test_hypothesis_1(df):
    """Проверка гипотезы о зависимости доли газа от смены."""
    print("Если ли различия в доле опасного газа от смены?\n")
    
    # Удаляем строки с NaN только для анализа 'stage_4_output_danger_gas'
    valid_df = df.dropna(subset=['stage_4_output_danger_gas'])

    # Разделение данных по сменам
    shift_1 = valid_df[valid_df['work_shift'] == 0]['stage_4_output_danger_gas']
    shift_2 = valid_df[valid_df['work_shift'] == 1]['stage_4_output_danger_gas']

    if shift_1.empty or shift_2.empty:
        print("Ошибка: Один из наборов данных пуст. Проверьте фильтрацию.")
        return

    # Основные статистические характеристики
    print("Основные статистические характеристики:")
    print_summary_statistics("Смена 1", shift_1)
    print_summary_statistics("Смена 2", shift_2)

    # Проверка нормальности распределения
    print("Проверка нормальности распределения:")
    shift_1_normal = is_normal_distribution(shift_1)
    shift_2_normal = is_normal_distribution(shift_2)

    # Проверка гипотез
    print("\nПроверка гипотез:")
    if shift_1_normal and shift_2_normal:
        # Если оба распределения нормальные, используем Student's t-test
        t_stat, p_value = ttest_ind(shift_1, shift_2, equal_var=False)  # Welch's t-test
        interpret_ttest(t_stat, p_value, shift_1, shift_2)
    else:
        # Если хотя бы одно распределение не является нормальным, используем Mann-Whitney U test
        u_stat, p_value = mannwhitneyu(shift_1, shift_2, alternative='two-sided')
        interpret_mannwhitney(u_stat, p_value, shift_1, shift_2)

print("Проверка гипотезы 1:")
test_hypothesis_1(df)
# Out:
# Проверка гипотезы 1:
# Если ли различия в доле опасного газа от смены?
#
# Основные статистические характеристики:
# Смена 1:
#   Среднее значение = 0.1407
#   Медиана = 0.1400
#   Стандартное отклонение = 0.0391
#   Размер выборки = 475
#
# Смена 2:
#   Среднее значение = 0.1395
#   Медиана = 0.1400
#   Стандартное отклонение = 0.0381
#   Размер выборки = 459
#
# Проверка нормальности распределения:
# Тест Шапиро-Уилка: W-статистика = 0.9736, p-значение = 1.47e-07
# Тест Шапиро-Уилка: W-статистика = 0.9840, p-значение = 5.92e-05
#
# Проверка гипотез:
# Mann-Whitney U Test:
#   U-статистика: 110984.0000, p-значение: 0.6314
#   Результат: Статистически значимых различий между сменами нет.

# %% [markdown]
# > На основе **p-value** можно понять, что нам не удалось опровергнуть нулевую гипотезу: нет различий в доле опасного газа от смены.

# %% [markdown]
# ### Проверка гипотезы 2

# %% [markdown]
# 1. **Нулевая гипотеза**: Распределение температур для обеих смен одинаково.
# 2. **Альтернативная гипотеза**: Распределения (или средние) различны, и у более эффективной смены значения будут значительно ниже.

# %%
def test_hypothesis_2(df):
    """Проверка гипотезы о зависимости температуры на этапе 3 от смены."""
    print("Какая из смен лучше управляет температурой верха на этапе 3? Считать, что высокая температура хуже.\n")
    
    # Извлечение данных по сменам
    shift_1 = df[df['work_shift'] == 0]['stage_3_output_temp_top']
    shift_2 = df[df['work_shift'] == 1]['stage_3_output_temp_top']

    if shift_1.empty or shift_2.empty:
        print("Ошибка: Один из наборов данных пуст. Проверьте фильтрацию.")
        return

    # Основные статистические характеристики
    print("Основные статистические характеристики температуры на этапе 3:")
    print_summary_statistics("Смена 1", shift_1)
    print_summary_statistics("Смена 2", shift_2)

    # Проверка нормальности распределения
    print("Проверка нормальности распределения:")
    print("Смена 1:")
    shift_1_normal = is_normal_distribution(shift_1)
    print("Смена 2:")
    shift_2_normal = is_normal_distribution(shift_2)

    # Проверка гипотезы (сравнение средних)
    print("\nПроверка гипотезы (сравнение средних):")
    if shift_1_normal and shift_2_normal:
        t_stat, p_value = ttest_ind(shift_1, shift_2, equal_var=False)
        interpret_ttest(t_stat, p_value, shift_1, shift_2)
    else:
        # Если хотя бы одно распределение не является нормальным, используем Mann-Whitney U test
        print("Распределения ненормальные, используем Mann-Whitney U Test.")
        u_stat, p_value = mannwhitneyu(shift_1, shift_2, alternative='two-sided')
        interpret_mannwhitney(u_stat, p_value, shift_1, shift_2)

    # Определение смены с более низким средним значением температуры
    better_shift = "Смена 1" if shift_1.mean() < shift_2.mean() else "Смена 2"
    print(f"Смена с более низкой средней температурой: {better_shift}")
    print(f"(Средняя температура Смена 1 = {shift_1.mean():.4f}, Смена 2 = {shift_2.mean():.4f})")

draw_separation_line()
print("Проверка гипотезы 2:")
test_hypothesis_2(df)
# Out:
# ########################################################################################################################
#
#
# Проверка гипотезы 2:
# Какая из смен лучше управляет температурой верха на этапе 3? Считать, что высокая температура хуже.
#
# Основные статистические характеристики температуры на этапе 3:
# Смена 1:
#   Среднее значение = 42.7211
#   Медиана = 44.0800
#   Стандартное отклонение = 4.5433
#   Размер выборки = 2192
#
# Смена 2:
#   Среднее значение = 42.8463
#   Медиана = 44.1200
#   Стандартное отклонение = 4.3716
#   Размер выборки = 2048
#
# Проверка нормальности распределения:
# Смена 1:
# Тест Шапиро-Уилка: W-статистика = 0.8791, p-значение = 2.71e-38
# Смена 2:
# Тест Шапиро-Уилка: W-статистика = 0.8595, p-значение = 2.14e-39
#
# Проверка гипотезы (сравнение средних):
# Распределения ненормальные, используем Mann-Whitney U Test.
# Mann-Whitney U Test:
#   U-статистика: 2236396.0000, p-значение: 0.8367
#   Результат: Статистически значимых различий между сменами нет.
# Смена с более низкой средней температурой: Смена 1
# (Средняя температура Смена 1 = 42.7211, Смена 2 = 42.8463)

# %% [markdown]
# > На основе **p-value** можно понять, что нам не удалось опровергнуть нулевую гипотезу: нет различий в доле опасного газа от смены.

# %% [markdown]
# ### Проверка гипотезы 3

# %%
def test_hypothesis_3(df):
    """
    Проверяет, связана ли конверсия мономера на 1 этапе с количеством подаваемой воды на 2 этапе.
    """
    print("Конверсия мономера на 1 этапе влияет на количество подаваемой суммарной воды.\n")
    
    # Извлечение данных
    conversion = df['stage_1_output_konv_avd']  # Конверсия мономера на 1 этапе
    water_input = df['stage_2_input_water_sum']  # Количество подаваемой воды на 2 этапе

    if conversion.empty or water_input.empty:
        print("Ошибка: Данные для анализа отсутствуют. Проверьте исходный DataFrame.")
        return

    # Проверка нормальности распределения
    print("Проверка нормальности распределения:")
    print("Конверсия мономера:")
    conversion_normal = is_normal_distribution(conversion)
    print("Подача воды:")
    water_input_normal = is_normal_distribution(water_input)

    # Выбор метода корреляции
    print("\nАнализ корреляции:")
    if conversion_normal and water_input_normal:
        print("Обе переменные нормально распределены. Применяем корреляцию Пирсона.")
        corr, p_value = pearsonr(conversion, water_input)
        method = "Пирсона"
    else:
        print("Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.")
        corr, p_value = spearmanr(conversion, water_input)
        method = "Спирмена"

    # Результаты корреляции
    print("\nРезультаты корреляционного анализа:")
    print(f"Коэффициент корреляции ({method}): {corr:.4f}")
    print(f"p-значение: {p_value:.4e}")

    # Интерпретация результатов
    if p_value < 0.05:
        print("Отклоняем нулевую гипотезу: Есть значимая связь между конверсией мономера и количеством подаваемой воды.")
        correlation_strength(corr)
    else:
        print("Не удается отклонить нулевую гипотезу: Значимой связи между конверсией мономера и количеством подаваемой воды нет.")

    # Построение графика
    print("\nВизуализация корреляции:")
    sns.scatterplot(x=conversion, y=water_input)
    plt.title("Связь между конверсией мономера и подачей воды")
    plt.xlabel("Конверсия мономера (%)")
    plt.ylabel("Подаваемая вода (м³)")
    plt.show()

draw_separation_line()
print("Проверка гипотезы 3:")
test_hypothesis_3(df)
# Out:
# ########################################################################################################################
#
#
# Проверка гипотезы 3:
# Конверсия мономера на 1 этапе влияет на количество подаваемой суммарной воды.
#
# Проверка нормальности распределения:
# Конверсия мономера:
# Тест Шапиро-Уилка: W-статистика = 0.9700, p-значение = 6.78e-29
# Подача воды:
# Тест Шапиро-Уилка: W-статистика = 0.9878, p-значение = 1.20e-18
#
# Анализ корреляции:
# Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.
#
# Результаты корреляционного анализа:
# Коэффициент корреляции (Спирмена): 0.0112
# p-значение: 4.6615e-01
# Не удается отклонить нулевую гипотезу: Значимой связи между конверсией мономера и количеством подаваемой воды нет.
#
# Визуализация корреляции:

# %% [markdown]
# ### Проверка гипотезы 4

# %% [markdown]
# Количество выходного количества продукта (`stage_4_output_product`) связано с долей опасного газа (`stage_4_output_danger_gas`)

# %%
def test_hypothesis_4(df):
    """
    Проверяет, связана ли доля опасного газа с количеством выходного продукта.
    """
    print("Количество выходного количества продукта связано с долей опасного газа.\n")
    
    # Извлечение данных
    valid_df = df.dropna(subset=['stage_4_output_danger_gas'])
    danger_gas = valid_df['stage_4_output_danger_gas']  # Доля опасного газа
    output_product = valid_df['stage_4_output_product']  # Количество выходного продукта

    if danger_gas.empty or output_product.empty:
        print("Ошибка: Данные для анализа отсутствуют. Проверьте исходный DataFrame.")
        return

    # Проверка нормальности распределения
    print("Проверка нормальности распределения:")
    print("Доля опасного газа:")
    danger_gas_normal = is_normal_distribution(danger_gas)
    print("Выход продукта:")
    output_product_normal = is_normal_distribution(output_product)

    # Выбор метода корреляции
    print("\nАнализ корреляции:")
    if danger_gas_normal and output_product_normal:
        print("Обе переменные нормально распределены. Применяем корреляцию Пирсона.")
        corr, p_value = pearsonr(danger_gas, output_product)
        method = "Пирсона"
    else:
        print("Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.")
        corr, p_value = spearmanr(danger_gas, output_product)
        method = "Спирмена"

    # Результаты корреляции
    print("\nРезультаты корреляционного анализа:")
    print(f"Коэффициент корреляции ({method}): {corr:.4f}")
    print(f"p-значение: {p_value:.4e}")

    # Интерпретация результатов
    if p_value < 0.05:
        print("Отклоняем нулевую гипотезу: Есть значимая связь между долей опасного газа и количеством выходного продукта.")
        print(correlation_strength(corr))
    else:
        print("Не удается отклонить нулевую гипотезу: Значимой связи между долей опасного газа и количеством выходного продукта нет.")

    # Построение графика
    print("\nВизуализация корреляции:")
    sns.scatterplot(x=danger_gas, y=output_product)
    plt.title("Связь между долей опасного газа и количеством выходного продукта")
    plt.xlabel("Доля опасного газа")
    plt.ylabel("Выход продукта")
    plt.show()



draw_separation_line()
print("Проверка гипотезы 4:")
test_hypothesis_4(df)
# Out:
# ########################################################################################################################
#
#
# Проверка гипотезы 4:
# Количество выходного количества продукта связано с долей опасного газа.
#
# Проверка нормальности распределения:
# Доля опасного газа:
# Тест Шапиро-Уилка: W-статистика = 0.9795, p-значение = 3.41e-10
# Выход продукта:
# Тест Шапиро-Уилка: W-статистика = 0.9617, p-значение = 6.35e-15
#
# Анализ корреляции:
# Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.
#
# Результаты корреляционного анализа:
# Коэффициент корреляции (Спирмена): -0.0517
# p-значение: 1.1429e-01
# Не удается отклонить нулевую гипотезу: Значимой связи между долей опасного газа и количеством выходного продукта нет.
#
# Визуализация корреляции:

# %% [markdown]
# ### Проверка гипотезы 5

# %% [markdown]
# Входной полимер на этапе 4 влияет на количество выходного продукта на этапе 4.
#
# `stage_4_input_polymer` **->** `stage_4_output_product`

# %%
def test_hypothesis_5(df):
    """
    Проверяет, связана ли количество полимера на входе с количеством выходного продукта.
    """
    print("Входной полимер на этапе 4 влияет на количество выходного продукта на этапе 4.\n")
    # Извлечение данных
    input_polymer = df['stage_4_input_polymer']  # Количество полимера на входе
    output_product = df['stage_4_output_product']  # Количество выходного продукта

    if input_polymer.empty or output_product.empty:
        print("Ошибка: Данные для анализа отсутствуют. Проверьте исходный DataFrame.")
        return

    # Проверка нормальности распределения
    print("Проверка нормальности распределения:")
    print("Количество полимера на входе:")
    input_polymer_normal = is_normal_distribution(input_polymer)
    print("Выход продукта:")
    output_product_normal = is_normal_distribution(output_product)

    # Выбор метода корреляции
    print("\nАнализ корреляции:")
    if input_polymer_normal and output_product_normal:
        print("Обе переменные нормально распределены. Применяем корреляцию Пирсона.")
        corr, p_value = pearsonr(input_polymer, output_product)
        method = "Пирсона"
    else:
        print("Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.")
        corr, p_value = spearmanr(input_polymer, output_product)
        method = "Спирмена"

    # Результаты корреляции
    print("\nРезультаты корреляционного анализа:")
    print(f"Коэффициент корреляции ({method}): {corr:.4f}")
    print(f"p-значение: {p_value:.4e}")

    # Интерпретация результатов
    if p_value < 0.05:
        print("Отклоняем нулевую гипотезу: Есть значимая связь между количеством полимера на входе и количеством выходного продукта.")
        print(correlation_strength(corr))  # Determine correlation strength
    else:
        print("Не удается отклонить нулевую гипотезу: Значимой связи между количеством полимера на входе и количеством выходного продукта нет.")

    # Построение графика
    print("\nВизуализация корреляции:")
    sns.scatterplot(x=input_polymer, y=output_product)
    plt.title("Связь между количеством полимера на входе и выходным продуктом")
    plt.xlabel("Количество полимера на входе")
    plt.ylabel("Выход продукта")
    plt.show()


draw_separation_line()
print("Проверка гипотезы 5:")
test_hypothesis_5(df)
# Out:
# ########################################################################################################################
#
#
# Проверка гипотезы 5:
# Входной полимер на этапе 4 влияет на количество выходного продукта на этапе 4.
# Проверка нормальности распределения:
# Количество полимера на входе:
# Тест Шапиро-Уилка: W-статистика = 0.9792, p-значение = 1.86e-24
# Выход продукта:
# Тест Шапиро-Уилка: W-статистика = 0.9625, p-значение = 7.99e-32
#
# Анализ корреляции:
# Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.
#
# Результаты корреляционного анализа:
# Коэффициент корреляции (Спирмена): 0.1436
# p-значение: 5.6914e-21
# Отклоняем нулевую гипотезу: Есть значимая связь между количеством полимера на входе и количеством выходного продукта.
# Связь слабая.
#
# Визуализация корреляции:

# %% [markdown]
# ### Проверка гипотезы 6

# %% [markdown]
# Вакуум низа на этапе 2 влияет на количество выходного продукта на этапе 4.
#
# `stage_2_output_top_vacuum` **->** `stage_4_output_product`

# %%
def test_hypothesis_6(df):
    """
    Проверяет, связана ли вакуум на 2 этапе с продуктом на 4 этапе.
    """
    print("Вакуум низа на этапе 2 влияет на количество выходного продукта на этапе 4.\n")
    # Извлечение данных
    top_vacuum = df['stage_2_output_top_vacuum']  # Вакуум на 2 этапе
    product_output = df['stage_4_output_product']  # Продукт на 4 этапе

    if top_vacuum.empty or product_output.empty:
        print("Ошибка: Данные для анализа отсутствуют. Проверьте исходный DataFrame.")
        return

    # Проверка нормальности распределения
    print("Проверка нормальности распределения:")
    print("Вакуум на 2 этапе:")
    top_vacuum_normal = is_normal_distribution(top_vacuum)
    print("Продукт на 4 этапе:")
    product_output_normal = is_normal_distribution(product_output)

    # Выбор метода корреляции
    print("\nАнализ корреляции:")
    if top_vacuum_normal and product_output_normal:
        print("Обе переменные нормально распределены. Применяем корреляцию Пирсона.")
        corr, p_value = pearsonr(top_vacuum, product_output)
        method = "Пирсона"
    else:
        print("Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.")
        corr, p_value = spearmanr(top_vacuum, product_output)
        method = "Спирмена"

    # Результаты корреляции
    print("\nРезультаты корреляционного анализа:")
    print(f"Коэффициент корреляции ({method}): {corr:.4f}")
    print(f"p-значение: {p_value:.4e}")

    # Интерпретация результатов
    if p_value < 0.05:
        print("Отклоняем нулевую гипотезу: Есть значимая связь между вакуумом на 2 этапе и продуктом на 4 этапе.")
        print(correlation_strength(corr))  # Determine correlation strength
    else:
        print("Не удается отклонить нулевую гипотезу: Значимой связи между вакуумом на 2 этапе и продуктом на 4 этапе нет.")

    # Построение графика
    print("\nВизуализация корреляции:")
    sns.scatterplot(x=top_vacuum, y=product_output)
    plt.title("Связь между вакуумом на 2 этапе и продуктом на 4 этапе")
    plt.xlabel("Вакуум на 2 этапе")
    plt.ylabel("Продукт на 4 этапе")
    plt.show()


draw_separation_line()
print("Проверка гипотезы 6:")
test_hypothesis_6(df)
# Out:
# ########################################################################################################################
#
#
# Проверка гипотезы 6:
# Вакуум низа на этапе 2 влияет на количество выходного продукта на этапе 4.
#
# Проверка нормальности распределения:
# Вакуум на 2 этапе:
# Тест Шапиро-Уилка: W-статистика = 0.9481, p-значение = 2.63e-36
# Продукт на 4 этапе:
# Тест Шапиро-Уилка: W-статистика = 0.9625, p-значение = 7.99e-32
#
# Анализ корреляции:
# Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.
#
# Результаты корреляционного анализа:
# Коэффициент корреляции (Спирмена): -0.0034
# p-значение: 8.2476e-01
# Не удается отклонить нулевую гипотезу: Значимой связи между вакуумом на 2 этапе и продуктом на 4 этапе нет.
#
# Визуализация корреляции:

# %% [markdown]
# ### Проверка гипотезы 7

# %% [markdown]
# Среднее содержание сухого остатка на этапе 4 зависит от температуры на верху на этапе 3.
#
# `stage_3_output_temp_top` -> `stage_4_output_dry_residue_avg`

# %%
def test_hypothesis_7(df):
    """
    Проверяет, связана ли температура верха на 3 этапе с средним остатком на 4 этапе.
    """
    print("Среднее содержание сухого остатка на этапе 4 зависит от температуры на верху на этапе 3.\n")
    # Извлечение данных
    temp_top = df['stage_3_output_temp_top']  # Температура верха на 3 этапе
    dry_residue_avg = df['stage_4_output_dry_residue_avg']  # Средний остаток на 4 этапе

    if temp_top.empty or dry_residue_avg.empty:
        print("Ошибка: Данные для анализа отсутствуют. Проверьте исходный DataFrame.")
        return

    # Проверка нормальности распределения
    print("Проверка нормальности распределения:")
    print("Температура верха на 3 этапе:")
    temp_top_normal = is_normal_distribution(temp_top)
    print("Средний остаток на 4 этапе:")
    dry_residue_avg_normal = is_normal_distribution(dry_residue_avg)

    # Выбор метода корреляции
    print("\nАнализ корреляции:")
    if temp_top_normal and dry_residue_avg_normal:
        print("Обе переменные нормально распределены. Применяем корреляцию Пирсона.")
        corr, p_value = pearsonr(temp_top, dry_residue_avg)
        method = "Пирсона"
    else:
        print("Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.")
        corr, p_value = spearmanr(temp_top, dry_residue_avg)
        method = "Спирмена"

    # Результаты корреляции
    print("\nРезультаты корреляционного анализа:")
    print(f"Коэффициент корреляции ({method}): {corr:.4f}")
    print(f"p-значение: {p_value:.4e}")

    # Интерпретация результатов
    if p_value < 0.05:
        print("Отклоняем нулевую гипотезу: Есть значимая связь между температурой верха на 3 этапе и средним остатком на 4 этапе.")
        print(correlation_strength(corr))  # Определение силы корреляции
    else:
        print("Не удается отклонить нулевую гипотезу: Значимой связи между температурой верха на 3 этапе и средним остатком на 4 этапе нет.")

    # Построение графика
    print("\nВизуализация корреляции:")
    sns.scatterplot(x=temp_top, y=dry_residue_avg)
    plt.title("Связь между температурой верха на 3 этапе и средним остатком на 4 этапе")
    plt.xlabel("Температура верха на 3 этапе")
    plt.ylabel("Средний остаток на 4 этапе")
    plt.show()


draw_separation_line()
print("Проверка гипотезы 7:")
test_hypothesis_7(df)
# Out:
# ########################################################################################################################
#
#
# Проверка гипотезы 7:
# Среднее содержание сухого остатка на этапе 4 зависит от температуры на верху на этапе 3.
#
# Проверка нормальности распределения:
# Температура верха на 3 этапе:
# Тест Шапиро-Уилка: W-статистика = 0.8704, p-значение = 1.33e-50
# Средний остаток на 4 этапе:
# Тест Шапиро-Уилка: W-статистика = 0.9799, p-значение = 4.56e-24
#
# Анализ корреляции:
# Хотя бы одна переменная ненормально распределена. Применяем корреляцию Спирмена.
#
# Результаты корреляционного анализа:
# Коэффициент корреляции (Спирмена): 0.1965
# p-значение: 3.5151e-38
# Отклоняем нулевую гипотезу: Есть значимая связь между температурой верха на 3 этапе и средним остатком на 4 этапе.
# Связь слабая.
#
# Визуализация корреляции:

# %% [markdown]
# ### График корреляций

# %%
def visualize_correlation_matrix(correlation_matrix, title="The best graphic"): # красивый график ВСЕХ корреляций(колличественных)
    """
    Рисует график корреляций всех колличественных признаков(и не только, если надо).

    Аругменты:
        correlation_matrix:  Фрейм данных Pandas, представляющий корреляционную матрицу.
        threshold: Название графика.
    """
    for col in correlation_matrix.columns: # цикл повторяется по каждому столбцу корреляционной матрицы.
        correlation_matrix[col] = pd.to_numeric(correlation_matrix[col], errors='coerce') # спасает от вылета программы.

    #correlation_matrix_np = correlation_matrix.values # преобразует фрейм данных Pandas в массив NumPy

    plt.figure(figsize=(10, 8))
    plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest') # создание тепловой карты корреляций

    plt.colorbar(label='Correlation')

    plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=90)
    plt.yticks(range(len(correlation_matrix.index)), correlation_matrix.index)

    plt.title(title)
    plt.show()

# %%
if 'danger_category' in df.columns:
    df = df.drop('danger_category', axis=1)

columns = [col for col in df.columns if col != 'work_shift']

correlation_matrix_spearman = pd.DataFrame(index=columns, columns=columns)

# Файл запускается в main.ipynb
# Если запускаете здесь, поменяйте "analysing_environmental_issues.csv" на "../analysing_environmental_issues.csv"
for chunk in pd.read_csv("analysing_environmental_issues.csv", sep=',', chunksize=750): # считываем все данные
                                                                                        # порциями по 750 строк
  for col in chunk.columns[1:-1]: # замена пропусков медианой в каждом столбце
      median_val = chunk[col].median()
      chunk[col] = chunk[col].fillna(median_val)

  for col1 in columns: # вычисление коэффициентов корелляции для всех пар столбцов
        for col2 in columns:
            corr_spearman, p_value_spearman = spearmanr(chunk[col1], chunk[col2])

            correlation_matrix_spearman.loc[col1, col2] = corr_spearman
            #устанавливаем в качестве значения коэффициенты корреляции в нужную ячейку

# %%
visualize_correlation_matrix(correlation_matrix_spearman, 'Матрица корреляции Спирмена')
